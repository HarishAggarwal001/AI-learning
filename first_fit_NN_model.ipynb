# %% [markdown]
# <a href="https://colab.research.google.com/github/HarishAggarwal001/AI-learning/blob/main/first_fit_NN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.9.2

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Declare model inputs and outputs for training
xs = np.array([-1,  0, 1, 2, 3, 4], dtype=int)
ys = np.array([-3, -1, 1, 3, 5, 7], dtype=int)

# %%
# Train the model
model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 218ms/step - loss: 6.7249
# Epoch 2/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4791
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4952
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7173
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1016
# Epoch 6/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6135
# Epoch 7/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2260
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9176
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6715
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4746
# Epoch 11/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3164
# Epoch 12/1000
# ...

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 63ms/step
# [[198.99869]]
